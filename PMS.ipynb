# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import pmdarima as pm
import matplotlib.pyplot as plt

# %%
Location = f'G:\My Drive\proposal defense\pothole.csv'
df = pd.read_csv(Location)
df
# Out:
#              10           20           30           40           50  \
# 0   785683.4693  781892.9558  780661.5575  779746.7028  779086.2981
# 1   784628.8203  782977.8107  780742.1994  779679.1914  778906.1841
# 2   786275.3116  782158.4146  780628.2865  779749.8672  779388.5837
# 3   786302.6384  782045.0419  780883.8198  780230.1991  779313.4196
# 4   785704.0614  782256.4765  781162.8861  779960.9484  779627.9686
# ..          ...          ...          ...          ...          ...
# 95  786122.7609  782809.5343  781461.1049  780303.6909  779630.9864
# 96  786038.9662  782440.7492  780742.4482  780111.5915  779365.4213
# 97  786295.4214  782455.1039  781012.6125  780182.4211  779746.5030
# 98  785711.6238  783028.5264  781620.6305  780467.9415  779467.5066
# 99  785747.0485  783596.6256  781256.8211  779801.9944  779496.6860
#
#             100          400          700
# 0   777445.2828  776339.6673  776183.8870
# 1   777468.9442  776326.0835  776269.5597
# ...

# %%
sd = []
sd.append(df['10'].std())
sd.append(df['20'].std())
sd.append(df['30'].std())
sd.append(df['40'].std())
sd.append(df['50'].std())
sd.append(df['100'].std())
sd.append(df['400'].std())
sd.append(df['700'].std())
x = [10,20,30,40,50,100,400,700]

# %%
plt.plot(x,sd)
plt.xlabel('Scenario generated')
plt.ylabel('Standard deviation')
# Out:
# Text(0, 0.5, 'Standard deviation')
